# %% [markdown]
# **Question 1:**
# 	Diabetes Linear Regression example

# %%
print(__doc__)


# Code source: Jaques Grobler
# License: BSD 3 clause


import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes = datasets.load_diabetes()


# Use only one feature
diabetes_X = diabetes.data[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes.target[:-20]
diabetes_y_test = diabetes.target[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
#The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
#Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))

#Sum of Squared Error
print("Sum of Squared Error: %.2f"
      % (mean_squared_error(diabetes_y_test, diabetes_y_pred)*len(diabetes_X_test)))


# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Coefficients:
#  [ 938.23786125]
# Mean squared error: 2548.07
# Variance score: 0.47
# Sum of Squared Error: 50961.45

# %%
diabetes_X_all = diabetes.data
# Split the data into training/testing sets
diabetes_X_all_train = diabetes_X_all[:-20]
diabetes_X_all_test = diabetes_X_all[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes.target[:-20]
diabetes_y_test = diabetes.target[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_all_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_all_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
all_coeff = regr.coef_

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))
all_mse = mean_squared_error(diabetes_y_test, diabetes_y_pred)

# Sum of Squared Error
print("Sum of Squared Error: %.2f"
      % (mean_squared_error(diabetes_y_test, diabetes_y_pred)*len(diabetes_X_all_test)))


# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))
r2_all = r2_score(diabetes_y_test, diabetes_y_pred)
# Out:
# Coefficients:
#  [  3.03499549e-01  -2.37639315e+02   5.10530605e+02   3.27736980e+02
#   -8.14131709e+02   4.92814588e+02   1.02848452e+02   1.84606489e+02
#    7.43519617e+02   7.60951722e+01]
# Mean squared error: 2004.57
# Sum of Squared Error: 40091.35
# Variance score: 0.59

# %%
#Split into 10 folds

from sklearn.model_selection import LeaveOneOut
loo = LeaveOneOut()

mse = []

for train_db, test_db in loo.split(diabetes.data):
        regr.fit(diabetes.data[train_db], diabetes.target[train_db])
        y_pred = regr.predict(diabetes.data[test_db])
        print('Coefficients: \n', regr.coef_)
        print("Mean squared error: %.2f"% mean_squared_error(diabetes.target[test_db], y_pred))
        print("Sum of Squared Error: %.2f"% (mean_squared_error(diabetes.target[test_db], y_pred)*len(y_pred)))
        print('Variance score: %.2f' % r2_score(diabetes.target[test_db], y_pred))
        mse.append(mean_squared_error(diabetes.target[test_db], y_pred))
        

print("Avg. Mean Squared Error : ",np.mean(mse))
print("Std. Mean Squared Error : ",np.std(mse))
# Out:
# Coefficients:
#  [  -7.55218336 -236.87353691  524.18513631  323.73910409 -804.3128443
#   485.58559494  102.35871917  172.973537    757.61864887   64.34765436]
# Mean squared error: 3147.99
# Sum of Squared Error: 3147.99
# Variance score: 0.00
# Coefficients:
#  [ -10.23071371 -239.6432958   519.847277    324.20274512 -793.396817
#   478.3474091   100.43049286  175.59849875  752.35107219   68.25343171]
# Mean squared error: 50.21
# Sum of Squared Error: 50.21
# Variance score: 0.00
# Coefficients:
#  [  -5.92792197 -237.90088715  522.53771998  322.56537268 -801.13029999
#   482.07163164  103.82416045  177.22022162  754.53522484   65.25376001]
# Mean squared error: 1350.52
# Sum of Squared Error: 1350.52
# Variance score: 0.00
# Coefficients:
#  [  -6.23577029 -237.57278388  521.34173881  324.87954172 -780.93954124
#   465.80687323   98.80384939  176.68819367  745.24568431   67.48024593]
# Mean squared error: 1587.88
# Sum of Squared Error: 1587.88
# Variance score: 0.00
# ...

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import cross_validation
regr = linear_model.LinearRegression()

# k-fold cross Validation

cv= cross_validation.KFold(len(diabetes.data),n_folds =10)
cvres = [] #Cross Validation results

for train_cv, test_cv in cv:
    print("test size, train size",len(train_cv), len(test_cv))
    regr.fit(diabetes.data[train_cv], diabetes.target[train_cv])
    y_predict  = regr.predict(diabetes.data[test_cv])
    print("\n\n")
    print('Coefficients: \n', regr.coef_)
    print("Mean squared error: %.2f"% mean_squared_error(diabetes.target[test_cv], y_predict))
    print("Sum of Squared Error: %.2f"% (mean_squared_error(diabetes.target[test_cv], y_predict)*len(y_predict)))        
    print('Variance score: %.2f' % r2_score(diabetes.target[test_cv], y_predict))
    cvres.append(r2_score(diabetes.target[test_cv], y_predict))
 

print("Average Scores:")
print("\nVariance score Average: ",np.mean(cvres))

regr.fit(diabetes.data,diabetes.target)
y_predict = regr.predict(diabetes.data)

print("\n Variance score - all samples %.2f" %r2_score(diabetes.target, y_predict))
# Out:
# test size, train size 397 45
#
#
#
# Coefficients:
#  [  -9.35207221 -231.25935869  522.28500451  322.9065529  -633.34781888
#   401.62150256   -8.76480774  115.25791809  650.39226132   88.66074286]
# Mean squared error: 2533.85
# Sum of Squared Error: 114023.16
# Variance score: 0.56
# test size, train size 397 45
#
#
#
# Coefficients:
#  [ -21.11846535 -215.88640593  529.35821161  323.83044314 -948.59584272
#   607.30739517  162.55714013  189.10624282  803.30840477   86.70881806]
# Mean squared error: 2870.77
# Sum of Squared Error: 129184.55
# Variance score: 0.23
# test size, train size 398 44
#
#
#
# Coefficients:
#  [  44.59538444 -230.20810407  533.18081477  335.16932957 -989.99143477
#   602.00982274  239.60713172  279.80132481  820.70907004   25.69869348]
# Mean squared error: 3512.72
# Sum of Squared Error: 154559.83
# Variance score: 0.35
# test size, train size 398 44
#
#
#
# Coefficients:
#  [ -24.3926342  -247.60708344  503.88724153  330.70556115 -509.97724606
# ...

# %% [markdown]
# **Question 2:**

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

MSE_res = []
def true_fun(X):                         #Defining a general function
    return np.cos(1.5 * np.pi * X)       # The function is cosine(1.5*pi*x)

np.random.seed(0)                        #Random state = 0

n_samples = 30                          #define no of samples
degrees = [1, 4, 15]                    #define degrees   

X = np.sort(np.random.rand(n_samples))  #Random pick of 30 samples  
y = true_fun(X) + np.random.randn(n_samples) * 0.1  #Extra noise is added

plt.figure(figsize=(14, 5))             #Plt generation 
for i in range(len(degrees)):
    ax = plt.subplot(1, len(degrees), i + 1)
    plt.setp(ax, xticks=(), yticks=())

    polynomial_features = PolynomialFeatures(degree=degrees[i],
                                             include_bias=False)
    linear_regression = LinearRegression()
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    pipeline.fit(X[:, np.newaxis], y)                          # 30 samples are fit using linear regression and polynomial regression

    # Evaluate the models using crossvalidation
    scores = cross_val_score(pipeline, X[:, np.newaxis], y,    #Cross validation 
                             scoring="neg_mean_squared_error", cv=10)

    X_test = np.linspace(0, 1, 100)                            #Plotting the defined function
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]), label="Model")
    plt.plot(X_test, true_fun(X_test), label="True function")
    plt.scatter(X, y, edgecolor='b', s=20, label="Samples")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
    plt.legend(loc="best")
    plt.title("Degree {}\nMSE = {:.2e}(+/- {:.2e})".format(
        degrees[i], -scores.mean(), scores.std()))
    MSE_res.append(mean_squared_error(true_fun(X_test) ,pipeline.predict(X_test[:, np.newaxis])))
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
degr = ["1","4","15"]

for mdl,mse in enumerate(MSE_res):
    k=2
    n=30
    aic = (2*k)+n*np.log(mse)
    print("AIC " + degr[mdl] + " model:" , aic)
    bic = k*np.log(n)+n*np.log(mse)
    print("BIC " + degr[mdl] + " model", bic)
# Out:
# AIC 1 model: -45.4283947243
# BIC 1 model -42.6259999609
# AIC 4 model: -197.601914477
# BIC 4 model -194.799519714
# AIC 15 model: 74.2229716041
# BIC 15 model 77.0253663675

# %% [markdown]
# **Question 3:**

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
 
auto_features= ["mpg","cylinders","displacement","horsepower","weight","acceleration","modelyear","origin","carname"]

#Reading the data into the read_table function with spaces as the seperator and NA values set as '?'
autodata=pd.read_csv("auto-mpg.data.txt", header= None,names= auto_features, sep="\s+", na_values=["?"])
print (autodata)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# 5    15.0          8         429.0       198.0  4341.0          10.0
# 6    14.0          8         454.0       220.0  4354.0           9.0
# 7    14.0          8         440.0       215.0  4312.0           8.5
# 8    14.0          8         455.0       225.0  4425.0          10.0
# 9    15.0          8         390.0       190.0  3850.0           8.5
# 10   15.0          8         383.0       170.0  3563.0          10.0
# 11   14.0          8         340.0       160.0  3609.0           8.0
# 12   15.0          8         400.0       150.0  3761.0           9.5
# ...

# %%
# what is the Y (Dependent Variable)
y = df_auto["mpg"].values

# what are the X (Independent Variables)
data_cols = ["cylinders","displacement","weight","horsepower","acceleration","origin","modelyear"]#]
xall = df_auto[data_cols].values
# how many data do you want to test the data
test_size = 110    #Manipulate default = 1000

# for later use to calculate AIC and BIC
k = len(data_cols)+1

#Cleaning data to remove the Nan values 
cleanauto = autodata.dropna(axis=0,how='any')
n = cleanauto.shape[0]
data = cleanauto[data_cols]
target = cleanauto[target_cols]

#Zero Mean, Unit Variance
cleanauto = cleanauto.iloc[:,0:8]
preprocessing.scale(cleanauto, copy=False)
#print(autoscaled.var())

# Spliting data and target into train and test data
data_train = data[:-test_size]
data_test = data[-test_size:]

target_train = target[:-test_size]
target_test = target[-test_size:]

regrn = linear_model.LinearRegression()
onehotenc = OneHotEncoder(categorical_features = [0, -2,-1])
X_all = onehotencoder.fit_transform(X_all).toarray()
regrn.fit(data_train, target_train)
print("Regression Coefficients: ", regrn.coef_)
print("MSE :%.2f" %mean_squared_error(y,y_pred))
print("Variance explained, calculated by SK-learn method: %.2f" % regrn.score(data_test, target_test))
print("Residual Sum of squares: %.2f" % np.mean((regrn.predict(data_test) - target_test) ** 2))

print("The largest magnitude coefficient is ", np.max(np.abs(regr.coef_)))
print("The largest magnitude coefficient is ", regr.coef_[-10])
# Out:
# Regression Coefficients:  [[-0.36043785  0.00821318 -0.00525958 -0.01786726 -0.04976851  0.98485898
#    0.39087235]]
# Variance explained, calculated by SK-learn method: 0.26
# Residual Sum of squares: 33.85

# %%
#Regression Coefficients
from sklearn.metrics import mean_squared_error

meansq_er_total = mean_squared_error(target_test, regrn.predict(data_test))

# AIC and BIC for All coefficients
aic_total = (2*k) + n * np.log(meansq_er_total)
print("AIC for all coefficients: %.2f" % aic_total)
bic_total = k * np.log(n) + n * np.log(meansq_er_total)
print("BIC for all coefficients: %.2f" % bic_total)
# Out:
# AIC for all coefficients: 1396.66
# BIC for all coefficients: 1428.43

# %%
# indicate which coefficient is being calculated for the MSE
which_coefficient = 2

# Calculate MSE for largest magnitude coefficient
regrSingle = linear_model.LinearRegression()
data_train_single = (data_train.iloc[:, which_coefficient]).reshape((n-test_size, 1))
regrSingle.fit(data_train_single, target_train)
mean_sq_er_single = mean_squared_error(target_test, regrSingle.predict(data_train_single[-test_size:]))
# Calculate AIC and BIC

# AIC and BIC for one coefficients
small_k = 2
aic_single = (2*small_k) + n * np.log(mean_sq_er_single)
print("AIC for the selected coefficient: %.2f" % aic_single)
bic_single = small_k * np.log(n) + n * np.log(mean_sq_er_single)
print("BIC for the selected coefficient: %.2f" % bic_single)
# Out:
# AIC for the selected coefficient: 1966.41
# BIC for the selected coefficient: 1974.35
# C:\Users\Nivea\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %% [markdown]
# **EXTRA Credit**

# %%
from sklearn.preprocessing import PolynomialFeatures

# k-fold cross validation
cv = cross_validation.KFold(len(X),n_folds =10)

mse_res = []
deg = 2

for train,test in cv:
    polyfeat = PolynomialFeatures(degree=deg,interaction_only = True)
    linregr = LinearRegression()
    pipe = Pipeline([("Poly_features", polyfeat),("linear_regression",linregr)])
    pipe.fit(X[train],y[train])
    y_predict = pipe.predict(X[test])
    
    print("Mean squared error: %.2f"% mean_squared_error(y[test], y_predict))
    print("Sum of Squared Error: %.2f"% (mean_squared_error(y[test], y_predict)*len(y_predict)))
    print('Variance score: %.2f' % r2_score(y[test], y_predict))
    print('Coefficients: \n', regr.coef_)
    mse_res.append(mean_squared_error(y[test],y_predict))
    
MSE = np.mean(mse_res)

k = xall.shape[1]
n = len(y)
aic = (2*k) + n * np.log(mse)
print("AIC : ",aic)
bic = k * np.log(n) + n * np.log(mse)
print("BIC :",bic)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-366edb544ff4> in <module>()
#      11     linregr = LinearRegression()
#      12     pipe = Pipeline([("Poly_features", polyfeat),("linear_regression",linregr)])
# ---> 13     pipe.fit(X[train],y[train])
#      14     y_predict = pipe.predict(X[test])
#      15
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     246             This estimator
#     247         """
# --> 248         Xt, fit_params = self._fit(X, y, **fit_params)
#     249         if self._final_estimator is not None:
#     250             self._final_estimator.fit(Xt, y, **fit_params)
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     211                 Xt, fitted_transformer = fit_transform_one_cached(
# ...

# %% [markdown]
# **Question 5:**

# %%
import pandas
from sklearn.feature_extraction import DictVectorizer
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Question A

# Constant for the file name
titanic_file = "titanic3.csv"
# Read in the csv into a pandas data frame.
# I only choose the 8 columns by the problems.
target_columns = [0, 1, 3, 4, 5, 6, 8, 10]
titanic_data = pandas.read_csv(titanic_file, usecols=target_columns)
# Remove NaN values
titanic_data.dropna(inplace=True)

# Split into survivors and non-survivors
survivors = titanic_data[titanic_data['survived'] == 1]
print(len(survivors))
non_survivors = titanic_data[titanic_data['survived'] == 0]

# Continuous categories
continuous_variables = ["age", "fare", "sibsp"]
print ("________Continuous_Variables__________")

# Print out means for survivors
for variable in continuous_variables:
    print("%s mean = %.2f" % (variable, survivors[variable].mean()))

# Categorical categories
categorical_variables = ["pclass", "sex", "embarked"]

print ("________Categorical_Variables__________")

for variable in categorical_variables:
    print("Survivor " + variable + " mode = ", survivors[variable].mode().iloc[0])
# Out:
# 425
# ________Continuous_Variables__________
# age mean = 28.82
# fare mean = 53.26
# sibsp mean = 0.49
# ________Categorical_Variables__________
# Survivor pclass mode =  1
# Survivor sex mode =  female
# Survivor embarked mode =  S

# %%
# Question B
# Split into male and female passengers
male_passengers = titanic_data[titanic_data['sex'] == 'male']
female_passengers = titanic_data[titanic_data['sex'] == 'female']

# Modify categorical variables to exclude sex and include survived
categorical_variables = ["pclass", "survived", "embarked"]

# Printing Means
for vari in continuous_variables:
    print("Male %s Mean = %.2f" % (vari, male_passengers[vari].mean()))
    print("Female %s Mean = %.2f" % (vari, female_passengers[vari].mean()))
    
# Printing modes for male and female passengers

print ("________Categorical_Variables__________")

for variable in categorical_variables:
    print("Male " + variable + " mode = ", male_passengers[variable].mode().iloc[0])
    print("Female " + variable + " mode = ", female_passengers[variable].mode().iloc[0])

#Observed probability of survival of each sex    

mcount = len(male_passengers[male_passengers['survived'] == 1])
fcount = len(female_passengers[female_passengers['survived'] == 1])
total = fcount+mcount
print ("________Observed Probability________")
print("Male Survivors probability = ", (mcount/total))
print("Female Survivors probability = ", (fcount/total))
# Out:
# Male age Mean = 30.54
# Female age Mean = 28.58
# Male fare Mean = 28.64
# Female fare Mean = 50.15
# Male sibsp Mean = 0.44
# Female sibsp Mean = 0.62
# ________Categorical_Variables__________
# Male pclass mode =  3
# Female pclass mode =  3
# Male survived mode =  0
# Female survived mode =  1
# Male embarked mode =  S
# Female embarked mode =  S
# ________Observed Probability________
# Male Survivors probability =  0.3176470588235294
# Female Survivors probability =  0.6823529411764706

# %%
# Question C 
fc_passengers = titanic_data[titanic_data['pclass'] == 1]
sc_passengers = titanic_data[titanic_data['pclass'] == 2]
tc_passengers = titanic_data[titanic_data['pclass'] == 3]

categorical_variables = ["sex", "survived", "embarked"]


for var in continuous_variables:
    print("FirstClass %s Mean = %.2f" % (var, fc_passengers[var].mean()))
    print("SecondClass %s Mean = %.2f" % (var, sc_passengers[var].mean()))
    print("ThirdClass %s Mean = %.2f" % (var, tc_passengers[var].mean()))
    
    
print ("________Categorical_Variables__________")

for variable in categorical_variables:
    print("FirstClass " + variable + " mode = ", fc_passengers[variable].mode().iloc[0])
    print("SecondClass " + variable + " mode = ", sc_passengers[variable].mode().iloc[0])
    print("ThirdClass " + variable + " mode = ", tc_passengers[variable].mode().iloc[0])

#Observed probability of survival of each sex    

fc_count = len(fc_passengers[fc_passengers['survived'] == 1])
sc_count = len(sc_passengers[sc_passengers['survived'] == 1])
tc_count = len(tc_passengers[tc_passengers['survived'] == 1])
total = fc_count+sc_count+tc_count
print ("________Observed Probability________")
print("First Class Survivors probability = ", (fc_count/total))
print("Second Class Survivors probability = ", (sc_count/total))
print("Third Class Survivors probability = ", (tc_count/total))
# Out:
# FirstClass age Mean = 39.08
# SecondClass age Mean = 29.51
# ThirdClass age Mean = 24.75
# FirstClass fare Mean = 92.32
# SecondClass fare Mean = 21.86
# ThirdClass fare Mean = 12.88
# FirstClass sibsp Mean = 0.48
# SecondClass sibsp Mean = 0.42
# ThirdClass sibsp Mean = 0.56
# ________Categorical_Variables__________
# FirstClass sex mode =  male
# SecondClass sex mode =  male
# ThirdClass sex mode =  male
# FirstClass survived mode =  1
# SecondClass survived mode =  0
# ThirdClass survived mode =  0
# FirstClass embarked mode =  S
# SecondClass embarked mode =  S
# ThirdClass embarked mode =  S
# ________Observed Probability________
# First Class Survivors probability =  0.4211764705882353
# Second Class Survivors probability =  0.27058823529411763
# Third Class Survivors probability =  0.30823529411764705

# %%
# Question D
# Target column
target_column = ['survived']
# Data columns
data_columns = ['pclass', 'sex', 'sibsp', 'parch', 'fare', 'embarked']
# Split data into data and target
titanic_final_data = titanic_data[data_columns]
titanic_final_target = titanic_data[target_column]

# Convert data and target into dicts
titanic_dict_data = titanic_final_data.T.to_dict('dict').values()
titanic_dict_target = titanic_final_target.T.to_dict('dict').values()

# Make new vectorizer
vectorizer = DictVectorizer(sparse=False)

# Transform data and target
data = vectorizer.fit_transform(titanic_dict_data)
target = vectorizer.fit_transform(titanic_dict_target)
# Reshape target
target = target.reshape((titanic_data.shape[0], ))
# Create new logistic regression instance
classifier = LogisticRegression()
# Fit the model
classifier.fit(data, target)

# Cross Validation
scores = cross_val_score(classifier, data, target, cv=10)
print("10 fold scores are")
print(scores)
print("Average Accuracy = %.2f" % np.mean(scores))
print("\n\nCoefficients",np.round(classifier.coef_,2))
print("Intercept",np.round(classifier.intercept_,2))
# Out:
# 10 fold scores are
# [0.6952381  0.74285714 0.85714286 0.83809524 0.78095238 0.80769231
#  0.84615385 0.64423077 0.6407767  0.69902913]
# Average Accuracy = 0.76
#
#
# Coefficients [[ 0.93 -0.48  0.24  0.    0.07 -0.67  1.62 -0.93 -0.23]]
# Intercept [0.69]

# %%
# Question E
# Calculate the AIC and BIC using the correct information

log_ll = []
for j in range(len(titanic_final_data)):
    log_ll.append(np.log((1+np.exp(-(np.dot(classifier.coef_, data[j]) + classifier.intercept_)))))
    sum_logll = -np.sum(log_ll)
    
# +1 means adding the number of features+1
k = titanic_final_data.shape[1]+1
n = titanic_final_data.shape[0]
print (k,n)

aic_titanic = 2*k + 2* sum_logll
bic_titanic = k * np.log(n) + n * sum_logll

print("AIC : ",aic_titanic)
print("BIC : ", bic_titanic)
# Out:
# 7 1043
# AIC :  -2529.489283267815
# BIC :  -1326381.0122289807

# %% [markdown]
# **Question 6:**

# %%
cols = ["ID", "Diagnosis", 
       "M_radius", "SE_radius", "W_radius",
      "M_texture", "SE_texture", "W_texture",
      "M_perimeter", "SE_perimeter", "W_perimeter",
      "M_area", "SE_area", "W_area",
      "M_smoothness", "SE_smoothness", "W_smoothness",
      "M_compactness", "SE_compactness", "W_compactness",
      "M_concavity", "SE_concavity", "W_concavity",
      "M_concave points", "SE_concave points", "W_concave points",
      "M_symmetry", "SE_symmetry", "W_symmetry",
      "M_fract dimension", "SE_fract dimension", "W_fract dimension"]
wdbc = pd.read_csv("wdbc.data.txt", header=None, names=cols)
wdbc.head()
# Out:
#          ID Diagnosis  M_radius  SE_radius  W_radius  M_texture  SE_texture  \
# 0    842302         M     17.99      10.38    122.80     1001.0     0.11840
# 1    842517         M     20.57      17.77    132.90     1326.0     0.08474
# 2  84300903         M     19.69      21.25    130.00     1203.0     0.10960
# 3  84348301         M     11.42      20.38     77.58      386.1     0.14250
# 4  84358402         M     20.29      14.34    135.10     1297.0     0.10030
#
#    W_texture  M_perimeter  SE_perimeter        ...          W_concavity  \
# 0    0.27760       0.3001       0.14710        ...                25.38
# 1    0.07864       0.0869       0.07017        ...                24.99
# 2    0.15990       0.1974       0.12790        ...                23.57
# 3    0.28390       0.2414       0.10520        ...                14.91
# 4    0.13280       0.1980       0.10430        ...                22.54
#
#    M_concave points  SE_concave points  W_concave points  M_symmetry  \
# ...

# %%
X = wdbc[["SE_area"]].values
Y = wdbc["Diagnosis"].values

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import accuracy_score

#Encoding Y
labelenc_y = LabelEncoder()
y=labelenc_y.fit_transform(Y)

accuracy_res = []

cv = cross_validation.KFold(len(X), n_folds=10)

for i, (train_wdbc, test_wdbc) in enumerate(cv):
    regr.fit(X[train_wdbc], y[train_wdbc])
    y_pred = regr.predict(X[test_wdbc])
    
    for j in range(y_pred.shape[0]):
        if(y_pred[j]<0.5):
            y_pred[j] = 0
        else :
            y_pred[j] = 1
    print("Accuracy of ",i+1," trial :", accuracy_score(y_pred, y[test_wdbc]))
    accuracy_res.append(accuracy_score(y_pred, y[test_wdbc]))
    
    
print("Average Accuracy:",np.mean(accuracy_res))
# Out:
# Accuracy of  1  trial : 0.508771929825
# Accuracy of  2  trial : 0.80701754386
# Accuracy of  3  trial : 0.859649122807
# Accuracy of  4  trial : 0.684210526316
# Accuracy of  5  trial : 0.684210526316
# Accuracy of  6  trial : 0.929824561404
# Accuracy of  7  trial : 0.894736842105
# Accuracy of  8  trial : 0.789473684211
# Accuracy of  9  trial : 0.894736842105
# Accuracy of  10  trial : 0.875
# Average Accuracy: 0.792763157895

# %%
acc_res = []

cv = cross_validation.KFold(len(X), n_folds=10)

# Logistic regression
for i, (train_wdbc, test_wdbc) in enumerate(cv):
    
    clf = LogisticRegression()
    # Fitting the model
    clf.fit(X[train_wdbc], y[train_wdbc])
    y_pred = clf.predict(X[test_wdbc])
    
    print(i+1 ,"Trial Accuracy: ",accuracy_score(y_pred, y[test_wdbc]))
    acc_res.append(accuracy_score(y_pred, y[test_wdbc]))
    

print("\n")
print("Avg. Accuracy: ",np.mean(acc_res))
# Out:
# 1 Trial Accuracy:  0.561403508772
# 2 Trial Accuracy:  0.771929824561
# 3 Trial Accuracy:  0.859649122807
# 4 Trial Accuracy:  0.684210526316
# 5 Trial Accuracy:  0.736842105263
# 6 Trial Accuracy:  0.912280701754
# 7 Trial Accuracy:  0.877192982456
# 8 Trial Accuracy:  0.789473684211
# 9 Trial Accuracy:  0.894736842105
# 10 Trial Accuracy:  0.875
#
#
# Avg. Accuracy:  0.796271929825

# %%
#Using all features except the unique ID
X = wdbc[["M_radius", "SE_radius", "W_radius",
      "M_texture", "SE_texture", "W_texture",
      "M_perimeter", "SE_perimeter", "W_perimeter",
      "M_area", "SE_area", "W_area",
      "M_smoothness", "SE_smoothness", "W_smoothness",
      "M_compactness", "SE_compactness", "W_compactness",
      "M_concavity", "SE_concavity", "W_concavity",
      "M_concave points", "SE_concave points", "W_concave points",
      "M_symmetry", "SE_symmetry", "W_symmetry",
      "M_fract dimension", "SE_fract dimension", "W_fract dimension"]].values

y = wdbc["Diagnosis"].values
           
labelenc_y = LabelEncoder()
y = labelenc_y.fit_transform(y)
           
accuracy_results = []

cv = cross_validation.KFold(len(X), n_folds = 10)
           
print("Linear Regression")
for i, (train_wdbc, test_wdbc) in enumerate(cv):
    regr.fit(X[train_wdbc], y[train_wdbc])
    y_pred = regr.predict(X[test_wdbc])
           
    for j in range(y_pred.shape[0]):
        if(y_pred[j]<0.5):
            y_pred[j] = 0
        else :
            y_pred[j] = 1  
    print("Accuracy of ",i+1," trial :", accuracy_score(y_pred, y[test_wdbc]))
    accuracy_results.append(accuracy_score(y_pred, y[test_wdbc]))
    
    
print("Average Accuracy:",np.mean(accuracy_results))        
print("\n\n")          
print("Logistic Regression")           

acc_res = []

cv = cross_validation.KFold(len(X), n_folds=10)

# Logistic regression
for i, (train_wdbc, test_wdbc) in enumerate(cv):
    
    clf = LogisticRegression()
    # Fitting the model
    clf.fit(X[train_wdbc], y[train_wdbc])
    y_pred = clf.predict(X[test_wdbc])
    
    print(i+1 ,"Trial Accuracy: ",accuracy_score(y_pred, y[test_wdbc]))
    acc_res.append(accuracy_score(y_pred, y[test_wdbc]))
    

print("\n")
print("Avg. Accuracy: ",np.mean(acc_res))
# Out:
# Linear Regression
# Accuracy of  1  trial : 0.912280701754
# Accuracy of  2  trial : 0.947368421053
# Accuracy of  3  trial : 0.982456140351
# Accuracy of  4  trial : 0.912280701754
# Accuracy of  5  trial : 0.947368421053
# Accuracy of  6  trial : 0.982456140351
# Accuracy of  7  trial : 1.0
# Accuracy of  8  trial : 0.982456140351
# Accuracy of  9  trial : 0.982456140351
# Accuracy of  10  trial : 0.946428571429
# Average Accuracy: 0.959555137845
#
#
#
# Logistic Regression
# 1 Trial Accuracy:  0.877192982456
# 2 Trial Accuracy:  0.947368421053
# 3 Trial Accuracy:  0.947368421053
# 4 Trial Accuracy:  0.964912280702
# 5 Trial Accuracy:  0.964912280702
# 6 Trial Accuracy:  0.947368421053
# 7 Trial Accuracy:  0.982456140351
# 8 Trial Accuracy:  0.947368421053
# 9 Trial Accuracy:  0.947368421053
# 10 Trial Accuracy:  0.964285714286
#
#
# Avg. Accuracy:  0.949060150376

# %%
np.mean(y_pred)
# Out:
# 0.23214285714285715

# %%
wdbc["Diagnosis"].value_counts(normalize = True)
# Out:
# B    0.627417
# M    0.372583
# Name: Diagnosis, dtype: float64

# %% [markdown]
# **Question 7:**

# %%
import numpy as np
import pandas as pd
gredata = pd.read_csv("admissions.csv")
gredata["prestige"]=gredata["prestige"].astype("category")
    

gredata = gredata.dropna()

admitted = gredata[gredata["admit"] == 1]
notadmitted = gredata[gredata["admit"] == 0]
cont_var = ["gre","gpa"]
for var in cont_var:
    print("Admitted %s Mean = %.2f" % (var, admitted[var].mean()))
    print("Not Admitted %s Mean = %.2f" % (var, notadmitted[var].mean()))
# Out:
# Admitted gre Mean = 618.57
# Not Admitted gre Mean = 573.58
# Admitted gpa Mean = 3.49
# Not Admitted gpa Mean = 3.35

# %%
print("\nTotal admission rate : ",gredata["admit"].mean())
print("Therefore, if one always predicts declined, accuracy of classification is %.2f" % (1-gredata["admit"].mean()) )
# Out:
# Total admission rate :  0.31738035264483627
# Therefore, if one always predicts declined, accuracy of classification is 0.68

# %%
prestige_grp = gredata.groupby(by="prestige").mean()
print(prestige_grp)

print("")

for i in range(3) :
    for j in range(4) :
        a = prestige_grp.iloc[:,i]
        print("Probability of ",prestige_grp.columns[i] , "in prestige group",a.index[j],": %.2f" % a[j])
    print("")
# Out:
#              admit         gre       gpa
# prestige
# 1.0       0.540984  611.803279  3.453115
# 2.0       0.358108  596.621622  3.367365
# 3.0       0.231405  574.876033  3.432893
# 4.0       0.179104  570.149254  3.318358
#
# Probability of  admit in prestige group 1.0 : 0.54
# Probability of  admit in prestige group 2.0 : 0.54
# Probability of  admit in prestige group 3.0 : 0.36
# Probability of  admit in prestige group 4.0 : 0.23
#
# Probability of  gre in prestige group 1.0 : 611.80
# Probability of  gre in prestige group 2.0 : 611.80
# Probability of  gre in prestige group 3.0 : 596.62
# Probability of  gre in prestige group 4.0 : 574.88
#
# Probability of  gpa in prestige group 1.0 : 3.45
# Probability of  gpa in prestige group 2.0 : 3.45
# Probability of  gpa in prestige group 3.0 : 3.37
# Probability of  gpa in prestige group 4.0 : 3.43

# %%
from sklearn import preprocessing
from sklearn import cross_validation
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
X = gredata[["gre", "gpa","prestige"]].values
y = gredata["admit"].values
print(X.shape)
# Encoding the Independent Variable
labelenc_X = LabelEncoder()
X[:, -1] = labelenc_X.fit_transform(X[:, -1])
ohenc = OneHotEncoder(categorical_features = [-1])
X = ohenc.fit_transform(X).toarray()
print(X.shape)
acc_results = []

cv = cross_validation.KFold(len(X), n_folds=10)

# Fit linear regression 
for i, (train_gre, test_gre) in enumerate(cv):
    
    clf = LogisticRegression()
    # Fit the model
    clf.fit(X[train_gre], y[train_gre])
    y_pred = clf.predict(X[test_gre])
    
    
    print("Accuracy of trial: ",i+1 ,accuracy_score(y_pred, y[test_gre]))
    acc_results.append(accuracy_score(y_pred, y[test_gre]))
    

print("\n")
print("Avg. accuray: ",np.mean(acc_results))


print("\n")
# Cross Validation
score = cross_val_score(clf, X, y, cv=10)
print("10 fold scores are")
print(np.round(score,2))
print("Average Accuracy = %.2f" % np.mean(score))
print("\n\nCoefficients",np.round(clf.coef_,2))
print("Intercept",np.round(clf.intercept_,2))
print("")
# Out:
# (397, 3)
# (397, 6)
# Accuracy of trial:  1 0.7
# Accuracy of trial:  2 0.675
# Accuracy of trial:  3 0.8
# Accuracy of trial:  4 0.775
# Accuracy of trial:  5 0.775
# Accuracy of trial:  6 0.7
# Accuracy of trial:  7 0.575
# Accuracy of trial:  8 0.6410256410256411
# Accuracy of trial:  9 0.717948717948718
# Accuracy of trial:  10 0.6666666666666666
#
#
# Avg. accuray:  0.7025641025641026
#
#
# 10 fold scores are
# [0.83 0.57 0.72 0.72 0.72 0.7  0.72 0.64 0.74 0.67]
# Average Accuracy = 0.70
#
#
# Coefficients [[ 0.36 -0.3  -0.93 -1.07  0.    0.22]]
# Intercept [-1.94]

# %%
# Question E
# Calculate the AIC and BIC using the correct information
log_ll = []
for j in range(len(X)) :    
    log_ll.append( np.log((1 + np.exp(- (np.dot(clf.coef_,  X[j]) + clf.intercept_)  )  ) ) )
sum_logll =  -np.sum(log_ll)

# +1 means adding the number of features+1

k = X.shape[1]+1
n = X.shape[0]
print(k,n)
aic = 2*k + 2*sum_logll
bic = k*np.log(n) + 2*sum_logll
print("AIC: ",aic)
print("BIC: ",bic)
# Out:
# 7 397
# AIC:  -945.2903405634194
# BIC:  -917.402786598609

# %%
gredata["admit"].value_counts(normalize = True)
# Out:
# 0    0.68262
# 1    0.31738
# Name: admit, dtype: float64
